# %%
# Import packages
import requests
import pandas as pd
import glob # File path package

# %%
# Call Etherscan API 
contract_add = '0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb' # VeeFriends Contract Address 
address = "0x6abd9b8ac8797c4227868cef0b1e15d1a1aff48e" # Example

#url = "http://api.etherscan.io/api?module=account&action=tokennfttx&contractaddress=" + contract_add + "&page=1&offset=100&sort=asc&apikey=YourApiKeyToken"
url = "http://api.etherscan.io/api?module=account&action=tokennfttx&contractaddress=" + contract_add + "&address=" + address + "&page=1&offset=100&sort=asc&apikey=YourApiKeyToken"

# %%
response = requests.get(url)
address_content = response.json()
address_content
# Out:
# {'status': '1',
#  'message': 'OK-Missing/Invalid API Key, rate limit of 1/5sec applied',
#  'result': [{'blockNumber': '12421047',
#    'timeStamp': '1620842799',
#    'hash': '0xca047b9b577c805a0bc919f9d067b9b3665d1ee846c05911a5c9aec50c081f17',
#    'nonce': '2',
#    'blockHash': '0x21176d166141ce7e379b88c2348064b8907c3d938a6799a09f1c0531ac63afb2',
#    'from': '0x0000000000000000000000000000000000000000',
#    'contractAddress': '0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb',
#    'to': '0x6abd9b8ac8797c4227868cef0b1e15d1a1aff48e',
#    'tokenID': '8593',
#    'tokenName': 'VeeFriends',
#    'tokenSymbol': 'VFT',
#    'tokenDecimal': '0',
#    'transactionIndex': '309',
#    'gas': '280000',
#    'gasPrice': '497000000000',
#    'gasUsed': '264532',
#    'cumulativeGasUsed': '13693819',
#    'input': 'deprecated',
#    'confirmations': '1268506'},
#   {'blockNumber': '12421052',
#    'timeStamp': '1620842846',
#    'hash': '0xe504f9a19ecd54bdf07d281436b3eee6b59713696534d2b727249b964cd41151',
#    'nonce': '3',
#    'blockHash': '0x98047c608eb4fccc73b88ebccf10cd8ffd3646d882d98de659586b718dada4e0',
#    'from': '0x0000000000000000000000000000000000000000',
#    'contractAddress': '0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb',
#    'to': '0x6abd9b8ac8797c4227868cef0b1e15d1a1aff48e',
#    'tokenID': '8685',
#    'tokenName': 'VeeFriends',
#    'tokenSymbol': 'VFT',
#    'tokenDecimal': '0',
#    'transactionIndex': '123',
#    'gas': '280000',
#    'gasPrice': '515000000000',
#    'gasUsed': '267332',
#    'cumulativeGasUsed': '9112661',
#    'input': 'deprecated',
#    'confirmations': '1268501'},
#   {'blockNumber': '12486343',
#    'timeStamp': '1621716336',
#    'hash': '0x4b6b41ebc806161b89b1b09ebc7e5e04d1f9ef9313fe59995b1ce58415c4285b',
#    'nonce': '5',
#    'blockHash': '0x43e8773371d9b16e75291f3b56d173ddeb18cb87482569a1feef1de1b8bc8dc1',
#    'from': '0x0000000000000000000000000000000000000000',
#    'contractAddress': '0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb',
#    'to': '0x6abd9b8ac8797c4227868cef0b1e15d1a1aff48e',
#    'tokenID': '1664',
#    'tokenName': 'VeeFriends',
#    'tokenSymbol': 'VFT',
#    'tokenDecimal': '0',
#    'transactionIndex': '42',
#    'gas': '280000',
#    'gasPrice': '38000000000',
#    'gasUsed': '267332',
#    'cumulativeGasUsed': '4289425',
#    'input': 'deprecated',
#    'confirmations': '1203210'},
#   {'blockNumber': '13597692',
#    'timeStamp': '1636671486',
#    'hash': '0xdc414026c3b78740b0809d68d3989ebff3e2029e27b38d2736a3d66c48eefbf8',
#    'nonce': '17',
#    'blockHash': '0x62e247bd8ce2419b471b196ffee43854d2eebd798f05c1c62754490463258e34',
#    'from': '0x6abd9b8ac8797c4227868cef0b1e15d1a1aff48e',
#    'contractAddress': '0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb',
#    'to': '0xf0665251e50d3e4b73e9b197c19f2dd35302d213',
#    'tokenID': '8593',
#    'tokenName': 'VeeFriends',
#    'tokenSymbol': 'VFT',
#    'tokenDecimal': '0',
#    'transactionIndex': '206',
#    'gas': '103685',
#    'gasPrice': '227472814099',
#    'gasUsed': '94085',
#    'cumulativeGasUsed': '11445015',
#    'input': 'deprecated',
#    'confirmations': '91861'},
#   {'blockNumber': '13597843',
#    'timeStamp': '1636673500',
#    'hash': '0x0bafb1a566f4bebe9fa5386b779c0f7069b6dfc47173ad99e1aaf545483eec63',
#    'nonce': '18',
#    'blockHash': '0x5506a1f9a78339e7f845b95542bc0b1c4e5de44ff07546320abe69772fc15aa6',
#    'from': '0x6abd9b8ac8797c4227868cef0b1e15d1a1aff48e',
#    'contractAddress': '0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb',
#    'to': '0xf0665251e50d3e4b73e9b197c19f2dd35302d213',
#    'tokenID': '8685',
#    'tokenName': 'VeeFriends',
#    'tokenSymbol': 'VFT',
#    'tokenDecimal': '0',
#    'transactionIndex': '21',
#    'gas': '79091',
#    'gasPrice': '195020064432',
#    'gasUsed': '71491',
#    'cumulativeGasUsed': '1277142',
#    'input': 'deprecated',
#    'confirmations': '91710'},
#   {'blockNumber': '13597861',
#    'timeStamp': '1636673777',
#    'hash': '0xc9649d49705d0784f7dee32da691504e103e748167bc67f6a63f2706f1157bf9',
#    'nonce': '19',
#    'blockHash': '0x7cc145d3977c174c74beb13b7e5f2665d49ac2f2e8cff438dbd6a2eaa436db82',
#    'from': '0x6abd9b8ac8797c4227868cef0b1e15d1a1aff48e',
#    'contractAddress': '0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb',
#    'to': '0xf0665251e50d3e4b73e9b197c19f2dd35302d213',
#    'tokenID': '1664',
#    'tokenName': 'VeeFriends',
#    'tokenSymbol': 'VFT',
#    'tokenDecimal': '0',
#    'transactionIndex': '337',
#    'gas': '96191',
#    'gasPrice': '163293402124',
#    'gasUsed': '86591',
#    'cumulativeGasUsed': '16445042',
#    'input': 'deprecated',
#    'confirmations': '91692'}]}

# %% [markdown]
# <h3><center> Obtain Addresses

# %%
path = r'/Users/loomanke/Documents/Github/NFT_Project/DATA' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

# Read in and concat token address csv files 
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
# Limit data to token address holders 
token_owners = frame["From"].unique()

# %%
def divide_chunks(l, n):
    '''
    Input: list of token addresses 
    Output: nested list with 100 addresses in each list
    '''
      
    # looping till length l
    for i in range(0, len(l), n): 
        yield l[i:i + n]

n = 10
divided_token_owners = list(divide_chunks(token_owners, n))
#print(divided_token_owners)

# %% [markdown]
# <h3><center> Testing

# %% [markdown]
# Goal: Reading in the full list of addresses exceeds the limit of my API call. I subset the data into groups of 100 (nested list). I would like to read in each list object separately so as to not exceed my call limit.

# %%
import random
import time
sleep = 30

apiToken = '6GC1UPX46NE1QPVI9YKI9IPJMFVF6MHKM2' # API token 
eventTransfer = [] # Storing transacation data 
contract_add = '0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb' # VeeFriends Contract Address 

for token_owner in divided_token_owners: 
    for owner in token_owner:
        try: 
            address = str(owner)
            url = "http://api.etherscan.io/api?module=account&action=tokennfttx&contractaddress=" + contract_add + "&address=" + address + "&page=1&offset=100&sort=asc&apikey=" + apiToken
            response = requests.get(url)
            address_content = response.json()
            eventTransfer.append(address_content)
        except requests.exceptions.ConnectionError:
            r.status_code = "Connection refused"
    time.sleep(random.uniform(0, sleep))

# %%
pd.set_option('display.max_colwidth', -1) # or 199.
eventTransfer = pd.DataFrame(eventTransfer)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
# Filter only OK messages for now 
eventTransfer_OK = eventTransfer[eventTransfer['message'] == 'OK']
eventTransfer_OK['message'].value_counts()
eventTransfer_OK = eventTransfer_OK.reset_index()

# %%
# Loop through data to transform it to a pd df 
df = pd.DataFrame()
for x in range(len(eventTransfer_OK)): 
    trial = eventTransfer_OK['result'][x]
    df_1 = pd.DataFrame(trial) 
    df = df.append(df_1)

# %%
# Reset index 
df = df.reset_index()
# Drop unecessary columns 
df = df.drop('index', 1)
#df = df.drop('level_0', 1)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.

# %%
df.to_csv (r'/Users/loomanke/Documents/Github/NFT_Project/DATA/partial_transfer_data.csv', index = False, header=True)

# %%
df
# Out:
#       blockNumber   timeStamp  \
# 0      12417503    1620794381
# 1      12420222    1620831361
# 2      12433559    1621009420
# 3      12435115    1621029484
# 4      12440542    1621102213
# ...         ...           ...
# 12159  12486162    1621714058
# 12160  12486197    1621714468
# 12161  12486312    1621715955
# 12162  12499111    1621887017
# 12163  12531109    1622315702
#
#                                                                      hash  \
# 0      0x34a1df4e0b54829b5d17a39842dfe6a726e506240e219d981a27ee8fb4af9dd7
# 1      0x7510f1f6b3ac4ac041a49e0258f129aaa44ff9308f58c3600bfc65345d9a8734
# 2      0x09974ef814e2e06cf8275736e9592665d1bc2ceb8c702b1ec91c96001a4722e3
# 3      0xef5cdb7df7ca8b35031b74659e744c9b52cf3a4f38e6a3846cfe080683d25a27
# 4      0x39087e18bb2aa2cada83fb551d0285cf1350fc27a51163a959fd69c2e3d944a2
# ...                                                                   ...
# 12159  0x3a6dd0cb6fc9380418743af6dd3f9521ab25c4cbac76af7b34234730de34d718
# 12160  0x13f2fded75aa27d3d293a106228d4d34790795651f03b7a79d93293069b430c5
# 12161  0x168ef66548d1be5521f1c083d2ba7b94a7d0067e04b80cf4e057c6adea0787eb
# 12162  0xf54d7b151ef193cb4cf1adc1478587eb5ec8f2ded4a61bb989ff2728c4b5ec2f
# 12163  0x7557178a209ed60a2c62658af64f15b19b4221c3620bd0b4529e00d44bbf3ada
#
#       nonce  \
# 0      10
# 1      21
# 2      22
# 3      23
# 4      24
# ...    ..
# 12159  5
# 12160  6
# 12161  7
# 12162  8
# 12163  9
#
#                                                                 blockHash  \
# 0      0x5264dc762b01c09b4020ab9501404b00ac65d001b02668a61a88b6f423ee27a1
# 1      0xf4e0bc8c1062dea1b6ba8049eebf49487dbd4451a2032e3922afd98d8f9596f5
# 2      0xc97baa1a3d3769c76513b0a94732b73aa310ef5e66630e005cdbb6cd7e0d18ef
# 3      0x519d64b57972f3c6a3f112c581934dd51205ca1b645aaddbdd1e52e1d379458b
# 4      0xaa66f61e2d7ed648b71f9760452e17688d9323abb3e1d148e122d030f0525436
# ...                                                                   ...
# 12159  0x4607b2f7a4c6988b9dbcd15df50940ddd1af8c3acc31f45a73846d17ce9c78a3
# 12160  0x94c7c9198ec3d04ca07a1e38397ef34a524d86754895a99037e367ab1dec9fc9
# 12161  0x85a12122827b29e1993181522acc33682aa47547074417b153b9949d2f760c84
# 12162  0x2034fa0cdc753b1253e2d8d83979b54026816f34d836cb4bb50d0ff96a2e5a6b
# 12163  0x0742a08de7e6374ac6a30856907686a937f1c96255853327830231cd16025709
#
#                                              from  \
# 0      0x0000000000000000000000000000000000000000
# 1      0x0000000000000000000000000000000000000000
# 2      0x0000000000000000000000000000000000000000
# 3      0x0000000000000000000000000000000000000000
# 4      0x0000000000000000000000000000000000000000
# ...                                           ...
# 12159  0x0000000000000000000000000000000000000000
# 12160  0x0000000000000000000000000000000000000000
# 12161  0x0000000000000000000000000000000000000000
# 12162  0x0000000000000000000000000000000000000000
# 12163  0x0000000000000000000000000000000000000000
#
#                                   contractAddress  \
# 0      0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb
# 1      0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb
# 2      0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb
# 3      0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb
# 4      0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb
# ...                                           ...
# 12159  0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb
# 12160  0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb
# 12161  0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb
# 12162  0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb
# 12163  0xa3aee8bce55beea1951ef834b99f3ac60d1abeeb
#
#                                                to tokenID   tokenName  \
# 0      0x3cd3bf7db26df10ff229fe8f8650bb9f8d05f103  1565    VeeFriends
# 1      0x3cd3bf7db26df10ff229fe8f8650bb9f8d05f103  2021    VeeFriends
# 2      0x3cd3bf7db26df10ff229fe8f8650bb9f8d05f103  5335    VeeFriends
# 3      0x3cd3bf7db26df10ff229fe8f8650bb9f8d05f103  5981    VeeFriends
# 4      0x3cd3bf7db26df10ff229fe8f8650bb9f8d05f103  8078    VeeFriends
# ...                                           ...   ...           ...
# 12159  0x954a53b0ab767be7abfc0fdbca1f5bb32fc1e511  6276    VeeFriends
# 12160  0x954a53b0ab767be7abfc0fdbca1f5bb32fc1e511  1312    VeeFriends
# 12161  0x954a53b0ab767be7abfc0fdbca1f5bb32fc1e511  8932    VeeFriends
# 12162  0x954a53b0ab767be7abfc0fdbca1f5bb32fc1e511  5609    VeeFriends
# 12163  0x954a53b0ab767be7abfc0fdbca1f5bb32fc1e511  7999    VeeFriends
#
#       tokenSymbol tokenDecimal transactionIndex     gas      gasPrice gasUsed  \
# 0      VFT         0            246              280000  240000001459  272071
# 1      VFT         0            154              280000  311300000000  274871
# 2      VFT         0            128              280000  203000000000  274871
# 3      VFT         0            168              280000  150000000000  267332
# 4      VFT         0            143              280000  83000000000   267332
# ...    ...        ..            ...                 ...          ...      ...
# 12159  VFT         0            144              280000  49000000000   267332
# 12160  VFT         0            107              280000  48000000000   267332
# 12161  VFT         0            153              280000  48000000000   267332
# 12162  VFT         0            111              280000  110000000000  267332
# 12163  VFT         0            127              280000  35000000000   267332
#
#       cumulativeGasUsed       input confirmations
# 0      14725096          deprecated  1272050
# 1      9867095           deprecated  1269331
# 2      8119351           deprecated  1255994
# 3      8488897           deprecated  1254438
# 4      14593733          deprecated  1249011
# ...         ...                 ...      ...
# 12159  13642240          deprecated  1203802
# 12160  7269720           deprecated  1203767
# 12161  12229313          deprecated  1203652
# 12162  8738273           deprecated  1190853
# 12163  13900280          deprecated  1158855
#
# [12164 rows x 19 columns]

# %% [markdown]
# <h3><center> Address Information

# %%
# Current Ether for single address 
/api?module=account&action=balance&address=0xddbd2b932c763ba5b1b7ae3b362eac3e8d40121a&tag=latest&apikey=YourApiKeyToken 

# Current Ether for multiple addresses 
/api?module=account&action=balancehistory&address=0xddbd2b932c763ba5b1b7ae3b362eac3e8d40121a&blockno=8000000&apikey=YourApiKeyToken

# Normal transactions by address 
/api?module=account&action=txlist&address=0xddbd2b932c763ba5b1b7ae3b362eac3e8d40121a&startblock=0&endblock=99999999&sort=asc&apikey=YourApiKeyToken

# %%
address = '0x86a457579412f9c0a76b60fe9bf33a9f76d17039'

# %%
url = 'http://api.etherscan.io/api?module=account&action=balance&address=' + address + '&tag=latest&apikey=YourApiKeyToken'

# %%
response = requests.get(url)
address_content = response.json()
address_content
# Out:
# {'status': '1',
#  'message': 'OK-Missing/Invalid API Key, rate limit of 1/5sec applied',
#  'result': '15927892396108346065'}

# %%
url = 'https://opensea.io/0x86a457579412f9c0a76b60fe9bf33a9f76d17039'

# %%
from bs4 import BeautifulSoup
page = requests.get(url)
page.status_code
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('a')
# Out:
# [<a href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" rel="noopener noreferrer" target="_blank">Cloudflare</a>]

# %%
url = 'https://etherscan.io/address/0xa2f13e7bdd23f06763b1e567be7b811a48c47236'

# %%
page = requests.get(url)
page.status_code
# Out:
# 403
